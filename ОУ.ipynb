# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
alpha=[0,1,25]
delta_t=math.pi/200

# %%
x1=np.zeros(101) # parametr
x2=np.zeros(101)
psi1=np.zeros(101)
psi2=np.zeros(101) # parametr
u=np.zeros(101)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***alpha = 0***

# %% [markdown]
# **Первый цикл метода Ньютона**

# %% [markdown]
# Первый расчет для  метода Ньютона

# %%
x1[0]=1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=1 # parametr

X1=x1[0]
Psi2=psi2[0]

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_1=x1[100]-0
d_x2_1=x2[100]-1

print('\nНевязки: ', d_x1_1,d_x2_1)
# Out:
#             0         1         2         3
# 0    1.000000  0.000000  2.000000  1.000000
# 1    1.000000 -0.007854  2.015708  0.968584
# 2    0.999877 -0.015955  2.030922  0.936921
# 3    0.999626 -0.024302  2.045640  0.905020
# 4    0.999244 -0.032896  2.059856  0.872887
# ..        ...       ...       ...       ...
# 96  -0.001087 -1.487968  1.137235 -1.956152
# 97  -0.024460 -1.503315  1.106508 -1.974015
# 98  -0.048074 -1.518434  1.075500 -1.991396
# 99  -0.071926 -1.533319  1.044220 -2.008290
# 100 -0.096011 -1.547963  1.012673 -2.024693
#
# [101 rows x 4 columns]
#
# Невязки:  -0.09601108961498003 -2.5479627002631036

# %% [markdown]
# Второй расчет для  метода Ньютона

# %%
delta_psi2=0.01

x1[0]=1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=1+delta_psi2 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_2=x1[100]-0
d_x2_2=x2[100]-1

print('\nНевязки: ', d_x1_2,d_x2_2)
# Out:
#             0         1         2         3
# 0    1.000000  0.000000  2.000000  1.010000
# 1    1.000000 -0.007775  2.015865  0.978584
# 2    0.999878 -0.015798  2.031237  0.946919
# 3    0.999630 -0.024067  2.046111  0.915012
# 4    0.999252 -0.032582  2.060484  0.882872
# ..        ...       ...       ...       ...
# 96   0.002715 -1.485144  1.147334 -1.955515
# 97  -0.020613 -1.500545  1.116617 -1.973537
# 98  -0.044184 -1.515721  1.085617 -1.991077
# 99  -0.067993 -1.530665  1.054341 -2.008130
# 100 -0.092036 -1.545369  1.022798 -2.024692
#
# [101 rows x 4 columns]
#
# Невязки:  -0.09203634628946919 -2.545368721903001

# %% [markdown]
# Третий расчет для  метода Ньютона

# %%
delta_x1=0.01

x1[0]=1+delta_x1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=1 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_3=x1[100]-0
d_x2_3=x2[100]-1

print('\nНевязки: ', d_x1_3,d_x2_3)
# Out:
#             0         1         2         3
# 0    1.010000  0.000000  2.020000  1.000000
# 1    1.010000 -0.008011  2.035708  0.968270
# 2    1.009874 -0.016271  2.050918  0.936293
# 3    1.009619 -0.024781  2.065625  0.904077
# 4    1.009229 -0.033539  2.079826  0.871631
# ..        ...       ...       ...       ...
# 96  -0.004901 -1.505672  1.138509 -1.976350
# 97  -0.028552 -1.521117  1.107464 -1.994234
# 98  -0.052445 -1.536332  1.076139 -2.011630
# 99  -0.076578 -1.551307  1.044540 -2.028534
# 100 -0.100946 -1.566036  1.012676 -2.044941
#
# [101 rows x 4 columns]
#
# Невязки:  -0.1009459438366399 -2.566036305625836

# %% [markdown]
# Четвертый, завершающий первый цикл, расчет для  метода Ньютона

# %%
a11=(d_x1_2-d_x1_1)/0.01
a12=(d_x1_3-d_x1_1)/0.01
a21=(d_x2_2-d_x2_1)/0.01
a22=(d_x2_3-d_x2_1)/0.01

b1=a11*Psi2+a12*X1-d_x1_1
b2=a21*Psi2+a22*X1-d_x2_1

# %%
x1[0]=(b2*a11-b1*a21)/(a22*a11-a12*a21) # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=(b1*a22-b2*a12)/(a22*a11-a12*a21) # parametr
u[0]=psi2[0]/2

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])
  u[i]=psi2[i]/2

df = pd.DataFrame(np.array([x1,x2,psi1,psi2,u]).T)
print(df)

d_x1_4=x1[100]-0
d_x2_4=x2[100]-1

print('\nНевязки: ', d_x1_4,d_x2_4)
# Out:
#                 0         1         2         3         4
# 0   -6.732627e-01  0.000000 -1.346525 -0.835891 -0.417946
# 1   -6.732627e-01  0.004011 -1.359655 -0.814740 -0.407370
# 2   -6.731997e-01  0.008187 -1.372453 -0.793383 -0.396691
# 3   -6.730711e-01  0.012531 -1.384916 -0.771824 -0.385912
# 4   -6.728742e-01  0.017041 -1.397040 -0.750070 -0.375035
# ..            ...       ...       ...       ...       ...
# 96  -6.110836e-02  0.955859 -0.929898  1.306650  0.653325
# 97  -4.609377e-02  0.967081 -0.909373  1.321257  0.660629
# 98  -3.090289e-02  0.978182 -0.888619  1.335542  0.667771
# 99  -1.553764e-02  0.989157 -0.867640  1.349500  0.674750
# 100  1.298770e-13  1.000000 -0.846442  1.363129  0.681564
#
# [101 rows x 5 columns]
#
# Невязки:  1.2987701192290757e-13 2.0694557179012918e-13

# %% [markdown]
# обратный расчет для сошедшегося варианта

# %%
x1_inv=np.zeros(101) # parametr
x2_inv=np.zeros(101)
psi1_inv=np.zeros(101)
psi2_inv=np.zeros(101) # parametr
u_inv=np.zeros(101)

# %%
x1_inv[0]=x1[100] # parametr
x2_inv[0]=x2[100] # is done
psi1_inv[0]=psi1[100] # is done #???
psi2_inv[0]=psi2[100] # parametr
u_inv[0]=u[100]

for i in range(1,101):
  x1_inv[i]=x1_inv[i-1]-delta_t*x2_inv[i-1]
  x2_inv[i]=x2_inv[i-1]-delta_t*(psi2_inv[i-1]/2-x1_inv[i-1]*math.exp(-alpha[0]*x1_inv[i-1]))
  psi1_inv[i]=psi1_inv[i-1]-delta_t*(psi2_inv[i-1]*math.exp(-alpha[0]*x1_inv[i-1])*(1-alpha[0]*x1_inv[i-1]))
  psi2_inv[i]=psi2_inv[i-1]-delta_t*(-psi1_inv[i-1])
  u_inv[i]=psi2_inv[i]/2

df = pd.DataFrame(np.array([x1_inv,x2_inv,psi1_inv,psi2_inv,u_inv]).T)
print(df)

x1_inv=x1_inv[::-1]
x2_inv=x2_inv[::-1]
u_inv=u_inv[::-1]
# Out:
#                 0         1         2         3         4
# 0    1.298770e-13  1.000000 -0.846442  1.363129  0.681564
# 1   -1.570796e-02  0.989294 -0.867854  1.349833  0.674917
# 2   -3.124776e-02  0.978446 -0.889057  1.336201  0.668100
# 3   -4.661715e-02  0.967460 -0.910046  1.322236  0.661118
# 4   -6.181398e-02  0.956343 -0.930816  1.307941  0.653970
# ..            ...       ...       ...       ...       ...
# 96  -6.799068e-01  0.000511 -1.430522 -0.768047 -0.384023
# 97  -6.799148e-01 -0.004136 -1.418458 -0.790517 -0.395259
# 98  -6.798498e-01 -0.008608 -1.406040 -0.812798 -0.406399
# 99  -6.797146e-01 -0.012903 -1.393273 -0.834884 -0.417442
# 100 -6.795119e-01 -0.017023 -1.380159 -0.856770 -0.428385
#
# [101 rows x 5 columns]

# %%
xx = np.arange (0, math.pi/2+math.pi/200,math.pi/200)
plt.plot(xx, x1, color='green',label='x1')
plt.plot(xx, x1_inv, color='black',label='x1_int', linestyle='dotted')
plt.plot(xx, x2, color='red',label='x2')
plt.plot(xx, x2_inv, color='blue',label='x12_int', linestyle='dotted')
plt.xlabel("n")
plt.legend()
plt.title("Экстремаль при альфа=0")
plt.show()

# %%
plt.plot(xx, u, color='green',label='u')
plt.plot(xx, u_inv, color='red',label='u_int', linestyle='dotted')
plt.xlabel("n")
plt.legend()
plt.title("управление при альфа=0")
plt.show()

# %%
alpha[0]=alpha[1]
 #_______________________________________________________________________________________________________________________
x1=np.zeros(101) # parametr
x2=np.zeros(101)
psi1=np.zeros(101)
psi2=np.zeros(101) # parametr
u=np.zeros(101)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.7 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-0.8 # parametr

X1=x1[0]
Psi2=psi2[0]

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_1=x1[100]-0
d_x2_1=x2[100]-1

print('\nНевязки: ', d_x1_1,d_x2_1)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.7 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-0.8+delta_psi2 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_2=x1[100]-0
d_x2_2=x2[100]-1

print('\nНевязки: ', d_x1_2,d_x2_2)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.7+delta_x1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-0.8 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_3=x1[100]-0
d_x2_3=x2[100]-1

print('\nНевязки: ', d_x1_3,d_x2_3)
 #_______________________________________________________________________________________________________________________
a11=(d_x1_2-d_x1_1)/0.01
a12=(d_x1_3-d_x1_1)/0.01
a21=(d_x2_2-d_x2_1)/0.01
a22=(d_x2_3-d_x2_1)/0.01

b1=a11*Psi2+a12*X1-d_x1_1
b2=a21*Psi2+a22*X1-d_x2_1

x1[0]=(b2*a11-b1*a21)/(a22*a11-a12*a21) # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=(b1*a22-b2*a12)/(a22*a11-a12*a21) # parametr
u[0]=psi2[0]/2

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])
  u[i]=psi2[i]/2

df = pd.DataFrame(np.array([x1,x2,psi1,psi2,u]).T)
print(df)

d_x1_4=x1[100]-0
d_x2_4=x2[100]-1

print('\nНевязки: ', d_x1_4,d_x2_4)
# Out:
#             0         1         2         3
# 0   -0.700000  0.000000 -1.400000 -0.800000
# 1   -0.700000  0.015859 -1.443019 -0.778009
# 2   -0.699751  0.031891 -1.484856 -0.755342
# 3   -0.699250  0.048088 -1.525458 -0.732018
# 4   -0.698495  0.064440 -1.564775 -0.708056
# ..        ...       ...       ...       ...
# 96   0.408518  1.309604 -0.909825  1.618329
# 97   0.429089  1.318050 -0.899831  1.632620
# 98   0.449793  1.326484 -0.890299  1.646755
# 99   0.470630  1.334911 -0.881222  1.660740
# 100  0.491598  1.343337 -0.872596  1.674582
#
# [101 rows x 4 columns]
#
# Невязки:  0.49159839849206133 0.3433373988323516
#             0         1         2         3
# 0   -0.700000  0.000000 -1.400000 -0.790000
# 1   -0.700000  0.015938 -1.442482 -0.768009
# 2   -0.699750  0.032048 -1.483781 -0.745350
# 3   -0.699246  0.048323 -1.523846 -0.722043
# 4   -0.698487  0.064754 -1.562627 -0.698107
# ..        ...       ...       ...       ...
# 96   0.410282  1.308941 -0.897829  1.609256
# ...

# %% [markdown]
# Второй цикл

# %%
X1=x1[0]
Psi2=psi2[0]

x1[0]=X1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=Psi2+0.01 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_2=x1[100]-0
d_x2_2=x2[100]-1

print('\nНевязки: ', d_x1_2,d_x2_2)
 #_______________________________________________________________________________________________________________________
x1[0]=X1+0.01 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=Psi2 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_3=x1[100]-0
d_x2_3=x2[100]-1

print('\nНевязки: ', d_x1_3,d_x2_3)
 #_______________________________________________________________________________________________________________________
a11=(d_x1_2-d_x1_4)/0.01
a12=(d_x1_3-d_x1_4)/0.01
a21=(d_x2_2-d_x2_4)/0.01
a22=(d_x2_3-d_x2_4)/0.01

b1=a11*Psi2+a12*X1-d_x1_4
b2=a21*Psi2+a22*X1-d_x2_4

x1[0]=(b2*a11-b1*a21)/(a22*a11-a12*a21) # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=(b1*a22-b2*a12)/(a22*a11-a12*a21) # parametr
u[0]=psi2[0]/2

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])
  u[i]=psi2[i]/2

df = pd.DataFrame(np.array([x1,x2,psi1,psi2,u]).T)
print(df)

d_x1_4=x1[100]-0
d_x2_4=x2[100]-1

print('\nНевязки: ', d_x1_4,d_x2_4)
# Out:
#             0         1         2         3
# 0   -0.506990  0.000000 -1.013980 -1.817867
# 1   -0.506990 -0.001055 -1.085425 -1.801940
# 2   -0.507006 -0.001986 -1.156245 -1.784890
# 3   -0.507038 -0.002781 -1.226396 -1.766728
# 4   -0.507081 -0.003433 -1.295837 -1.747464
# ..        ...       ...       ...       ...
# 96  -0.064356  0.920348 -1.882446  1.922006
# 97  -0.049899  0.936522 -1.848177  1.951575
# 98  -0.035189  0.952673 -1.814345  1.980607
# 99  -0.020224  0.968802 -1.780985  2.009106
# 100 -0.005006  0.984905 -1.748130  2.037082
#
# [101 rows x 4 columns]
#
# Невязки:  -0.0050060653863744885 -0.015094741091379538
#             0         1         2         3
# 0   -0.496990  0.000000 -0.993980 -1.827867
# 1   -0.496990 -0.001524 -1.064631 -1.812254
# 2   -0.497014 -0.002925 -1.134680 -1.795531
# 3   -0.497060 -0.004193 -1.204084 -1.777707
# 4   -0.497126 -0.005320 -1.272806 -1.758794
# ..        ...       ...       ...       ...
# ...

# %%
X1=x1[0]
Psi2=psi2[0]

x1[0]=X1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=Psi2+0.01 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_2=x1[100]-0
d_x2_2=x2[100]-1

print('\nНевязки: ', d_x1_2,d_x2_2)
 #_______________________________________________________________________________________________________________________
x1[0]=X1+0.01 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=Psi2 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_3=x1[100]-0
d_x2_3=x2[100]-1

print('\nНевязки: ', d_x1_3,d_x2_3)
 #_______________________________________________________________________________________________________________________
a11=(d_x1_2-d_x1_4)/0.01
a12=(d_x1_3-d_x1_4)/0.01
a21=(d_x2_2-d_x2_4)/0.01
a22=(d_x2_3-d_x2_4)/0.01

b1=a11*Psi2+a12*X1-d_x1_4
b2=a21*Psi2+a22*X1-d_x2_4

x1[0]=(b2*a11-b1*a21)/(a22*a11-a12*a21) # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=(b1*a22-b2*a12)/(a22*a11-a12*a21) # parametr
u[0]=psi2[0]/2

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])
  u[i]=psi2[i]/2

df = pd.DataFrame(np.array([x1,x2,psi1,psi2,u]).T)
print(df)

d_x1_4=x1[100]-0
d_x2_4=x2[100]-1

print('\nНевязки: ', d_x1_4,d_x2_4)
# Out:
#             0         1         2         3
# 0   -0.512263  0.000000 -1.024526 -1.826320
# 1   -0.512263 -0.000914 -1.096936 -1.810227
# 2   -0.512277 -0.001701 -1.168707 -1.792996
# 3   -0.512304 -0.002352 -1.239798 -1.774638
# 4   -0.512341 -0.002858 -1.310163 -1.755163
# ..        ...       ...       ...       ...
# 96  -0.058312  0.933957 -1.892103  1.945408
# 97  -0.043642  0.950208 -1.857821  1.975129
# 98  -0.028716  0.966436 -1.823997  2.004311
# 99  -0.013535  0.982642 -1.790666  2.032963
# 100  0.001900  0.998825 -1.757859  2.061090
#
# [101 rows x 4 columns]
#
# Невязки:  0.0019000393972384098 -0.0011753576050405057
#             0         1         2         3
# 0   -0.502263  0.000000 -1.004526 -1.836320
# 1   -0.502263 -0.001385 -1.076131 -1.820541
# 2   -0.502285 -0.002647 -1.147121 -1.803637
# 3   -0.502326 -0.003774 -1.217454 -1.785618
# 4   -0.502386 -0.004759 -1.287090 -1.766494
# ..        ...       ...       ...       ...
# ...

# %%
X1=x1[0]
Psi2=psi2[0]

x1[0]=X1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=Psi2+0.01 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_2=x1[100]-0
d_x2_2=x2[100]-1

print('\nНевязки: ', d_x1_2,d_x2_2)
 #_______________________________________________________________________________________________________________________
x1[0]=X1+0.01 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=Psi2 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_3=x1[100]-0
d_x2_3=x2[100]-1

print('\nНевязки: ', d_x1_3,d_x2_3)
 #_______________________________________________________________________________________________________________________
a11=(d_x1_2-d_x1_4)/0.01
a12=(d_x1_3-d_x1_4)/0.01
a21=(d_x2_2-d_x2_4)/0.01
a22=(d_x2_3-d_x2_4)/0.01

b1=a11*Psi2+a12*X1-d_x1_4
b2=a21*Psi2+a22*X1-d_x2_4

x1[0]=(b2*a11-b1*a21)/(a22*a11-a12*a21) # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=(b1*a22-b2*a12)/(a22*a11-a12*a21) # parametr
u[0]=psi2[0]/2

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])
  u[i]=psi2[i]/2

df = pd.DataFrame(np.array([x1,x2,psi1,psi2,u]).T)
print(df)

d_x1_4=x1[100]-0
d_x2_4=x2[100]-1

print('\nНевязки: ', d_x1_4,d_x2_4)
# Out:
#             0         1         2         3
# 0   -0.512231  0.000000 -1.024463 -1.826470
# 1   -0.512231 -0.000916 -1.096875 -1.810378
# 2   -0.512246 -0.001706 -1.168649 -1.793148
# 3   -0.512273 -0.002359 -1.239741 -1.774791
# 4   -0.512310 -0.002868 -1.310109 -1.755317
# ..        ...       ...       ...       ...
# 96  -0.058387  0.933893 -1.892235  1.945414
# 97  -0.043717  0.950145 -1.857948  1.975137
# 98  -0.028792  0.966375 -1.824119  2.004321
# 99  -0.013613  0.982582 -1.790783  2.032975
# 100  0.001822  0.998766 -1.757970  2.061104
#
# [101 rows x 4 columns]
#
# Невязки:  0.0018217444245055142 -0.00123426054163156
#             0         1         2         3
# 0   -0.502231  0.000000 -1.004463 -1.836470
# 1   -0.502231 -0.001388 -1.076070 -1.820692
# 2   -0.502253 -0.002652 -1.147062 -1.803789
# 3   -0.502295 -0.003782 -1.217398 -1.785771
# 4   -0.502354 -0.004769 -1.287035 -1.766648
# ..        ...       ...       ...       ...
# ...

# %%
X1=x1[0]
Psi2=psi2[0]

x1[0]=X1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=Psi2+0.01 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_2=x1[100]-0
d_x2_2=x2[100]-1

print('\nНевязки: ', d_x1_2,d_x2_2)
 #_______________________________________________________________________________________________________________________
x1[0]=X1+0.01 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=Psi2 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_3=x1[100]-0
d_x2_3=x2[100]-1

print('\nНевязки: ', d_x1_3,d_x2_3)
 #_______________________________________________________________________________________________________________________
a11=(d_x1_2-d_x1_4)/0.01
a12=(d_x1_3-d_x1_4)/0.01
a21=(d_x2_2-d_x2_4)/0.01
a22=(d_x2_3-d_x2_4)/0.01

b1=a11*Psi2+a12*X1-d_x1_4
b2=a21*Psi2+a22*X1-d_x2_4

x1[0]=(b2*a11-b1*a21)/(a22*a11-a12*a21) # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=(b1*a22-b2*a12)/(a22*a11-a12*a21) # parametr
u[0]=psi2[0]/2

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])
  u[i]=psi2[i]/2

df = pd.DataFrame(np.array([x1,x2,psi1,psi2,u]).T)
print(df)

d_x1_4=x1[100]-0
d_x2_4=x2[100]-1

print('\nНевязки: ', d_x1_4,d_x2_4)
# Out:
#             0         1         2         3
# 0   -0.512231  0.000000 -1.024463 -1.826470
# 1   -0.512231 -0.000916 -1.096875 -1.810377
# 2   -0.512246 -0.001706 -1.168649 -1.793148
# 3   -0.512273 -0.002359 -1.239741 -1.774791
# 4   -0.512310 -0.002868 -1.310109 -1.755317
# ..        ...       ...       ...       ...
# 96  -0.058387  0.933893 -1.892235  1.945413
# 97  -0.043717  0.950145 -1.857947  1.975137
# 98  -0.028792  0.966375 -1.824119  2.004321
# 99  -0.013612  0.982582 -1.790782  2.032974
# 100  0.001822  0.998766 -1.757970  2.061104
#
# [101 rows x 4 columns]
#
# Невязки:  0.0018219653861379567 -0.0012341582690847952
#             0         1         2         3
# 0   -0.502231  0.000000 -1.004463 -1.836470
# 1   -0.502231 -0.001388 -1.076070 -1.820691
# 2   -0.502253 -0.002652 -1.147062 -1.803789
# 3   -0.502295 -0.003782 -1.217398 -1.785771
# 4   -0.502354 -0.004769 -1.287035 -1.766648
# ..        ...       ...       ...       ...
# ...

# %%
 #_______________________________________________________________________________________________________________________
x1_inv[0]=x1[100] # parametr
x2_inv[0]=x2[100] # is done
psi1_inv[0]=psi1[100] # is done #???
psi2_inv[0]=psi2[100] # parametr
u_inv[0]=u[100]

for i in range(1,101):
  x1_inv[i]=x1_inv[i-1]-delta_t*x2_inv[i-1]
  x2_inv[i]=x2_inv[i-1]-delta_t*(psi2_inv[i-1]/2-x1_inv[i-1]*math.exp(-alpha[0]*x1_inv[i-1]))
  psi1_inv[i]=psi1_inv[i-1]-delta_t*(psi2_inv[i-1]*math.exp(-alpha[0]*x1_inv[i-1])*(1-alpha[0]*x1_inv[i-1]))
  psi2_inv[i]=psi2_inv[i-1]-delta_t*(-psi1_inv[i-1])
  u_inv[i]=psi2_inv[i]/2

df = pd.DataFrame(np.array([x1_inv,x2_inv,psi1_inv,psi2_inv,u_inv]).T)
print(df)

x1_inv=x1_inv[::-1]
x2_inv=x2_inv[::-1]
u_inv=u_inv[::-1]
 #_______________________________________________________________________________________________________________________
plt.plot(xx, x1, color='green',label='x1')
plt.plot(xx, x1_inv, color='black',label='x1_int', linestyle='dotted')
plt.plot(xx, x2, color='red',label='x2')
plt.plot(xx, x2_inv, color='blue',label='x12_int', linestyle='dotted')
plt.xlabel("n")
plt.legend()
plt.title("Экстремаль при альфа=1")
plt.show()
 #_______________________________________________________________________________________________________________________
plt.plot(xx, u, color='green',label='u')
plt.plot(xx, u_inv, color='red',label='u_int', linestyle='dotted')
plt.xlabel("n")
plt.legend()
plt.title("управление при альфа=1")
plt.show()
# Out:
#                 0         1         2         3         4
# 0   -2.204286e-07  1.000000 -1.766424  2.068963  1.034481
# 1   -1.570818e-02  0.983750 -1.798924  2.041216  1.020608
# 2   -3.116090e-02  0.967468 -1.832006  2.012958  1.006479
# 3   -4.635785e-02  0.951153 -1.865643  1.984181  0.992091
# 4   -6.129853e-02  0.934807 -1.899803  1.954876  0.977438
# ..            ...       ...       ...       ...       ...
# 96  -5.060545e-01 -0.025947 -1.390057 -1.845149 -0.922574
# 97  -5.056469e-01 -0.024640 -1.317651 -1.866984 -0.933492
# 98  -5.052599e-01 -0.023147 -1.244439 -1.887681 -0.943841
# 99  -5.048963e-01 -0.021475 -1.170463 -1.907229 -0.953614
# 100 -5.045590e-01 -0.019636 -1.095766 -1.925615 -0.962807
#
# [101 rows x 5 columns]

# %%
alpha[0]=25
 #_______________________________________________________________________________________________________________________
x1=np.zeros(101) # parametr
x2=np.zeros(101)
psi1=np.zeros(101)
psi2=np.zeros(101) # parametr
u=np.zeros(101)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.5 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-1.8 # parametr

X1=x1[0]
Psi2=psi2[0]

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_1=x1[100]-0
d_x2_1=x2[100]-1

print('\nНевязки: ', d_x1_1,d_x2_1)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.5 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-1.8+delta_psi2 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_2=x1[100]-0
d_x2_2=x2[100]-1

print('\nНевязки: ', d_x1_2,d_x2_2)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.5+delta_x1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-1.8 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_3=x1[100]-0
d_x2_3=x2[100]-1

print('\nНевязки: ', d_x1_3,d_x2_3)
 #_______________________________________________________________________________________________________________________
a11=(d_x1_2-d_x1_1)/0.01
a12=(d_x1_3-d_x1_1)/0.01
a21=(d_x2_2-d_x2_1)/0.01
a22=(d_x2_3-d_x2_1)/0.01

b1=a11*Psi2+a12*X1-d_x1_1
b2=a21*Psi2+a22*X1-d_x2_1

x1[0]=(b2*a11-b1*a21)/(a22*a11-a12*a21) # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=(b1*a22-b2*a12)/(a22*a11-a12*a21) # parametr
u[0]=psi2[0]/2

for i in range(1,101):
  print(i)
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])
  u[i]=psi2[i]/2

df = pd.DataFrame(np.array([x1,x2,psi1,psi2,u]).T)
print(df)

d_x1_4=x1[100]-0
d_x2_4=x2[100]-1

print('\nНевязки: ', d_x1_4,d_x2_4)
 #_______________________________________________________________________________________________________________________

x1_inv[0]=x1[100] # parametr
x2_inv[0]=x2[100] # is done
psi1_inv[0]=psi1[100] # is done #???
psi2_inv[0]=psi2[100] # parametr
u_inv[0]=u[100]

for i in range(1,101):
  x1_inv[i]=x1_inv[i-1]-delta_t*x2_inv[i-1]
  x2_inv[i]=x2_inv[i-1]-delta_t*(psi2_inv[i-1]/2-x1_inv[i-1]*math.exp(-alpha[0]*x1_inv[i-1]))
  psi1_inv[i]=psi1_inv[i-1]-delta_t*(psi2_inv[i-1]*math.exp(-alpha[0]*x1_inv[i-1])*(1-alpha[0]*x1_inv[i-1]))
  psi2_inv[i]=psi2_inv[i-1]-delta_t*(-psi1_inv[i-1])
  u_inv[i]=psi2_inv[i]/2

df = pd.DataFrame(np.array([x1_inv,x2_inv,psi1_inv,psi2_inv,u_inv]).T)
print(df)

x1_inv=x1_inv[::-1]
x2_inv=x2_inv[::-1]
u_inv=u_inv[::-1]
 #_______________________________________________________________________________________________________________________
plt.plot(xx, x1, color='green',label='x1')
plt.plot(xx, x1_inv, color='black',label='x1_int', linestyle='dotted')
plt.plot(xx, x2, color='red',label='x2')
plt.plot(xx, x2_inv, color='blue',label='x12_int', linestyle='dotted')
plt.xlabel("n")
plt.legend()
plt.title("Экстремаль при альфа=25")
plt.show()
 #_______________________________________________________________________________________________________________________
plt.plot(xx, u, color='green',label='u')
plt.plot(xx, u_inv, color='red',label='u_int', linestyle='dotted')
plt.xlabel("n")
plt.legend()
plt.title("управление при альфа=25")
plt.show()
# Out:
#                 0              1              2              3
# 0       -0.500000       0.000000      -1.000000      -1.800000
# 1       -0.500000    2107.501983 -102426.283434      -1.784292
# 2       32.604564    4215.004089 -203957.737652    1607.124006
# 3       98.813693    4227.626412 -203957.737652    4810.884657
# 4      165.221094    4265.411011 -203957.737652    8014.645308
# ..            ...            ...            ...            ...
# 96   60103.545211  115385.816539 -203957.737652  302760.625223
# 97   61916.021378  117763.692929 -203957.737652  305964.385874
# 98   63765.849141  120166.731596 -203957.737652  309168.146526
# 99   65653.423747  122594.932541 -203957.737652  312371.907177
# 100  67579.140444  125048.295763 -203957.737652  315575.667828
#
# [101 rows x 4 columns]
#
# Невязки:  67579.14044439496 125047.29576289056
#                 0              1              2              3
# 0       -0.500000       0.000000      -1.000000      -1.790000
# ...

# %%
alpha[0]=25
 #_______________________________________________________________________________________________________________________
x1=np.zeros(101) # parametr
x2=np.zeros(101)
psi1=np.zeros(101)
psi2=np.zeros(101) # parametr
u=np.zeros(101)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.3 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-1.9 # parametr

X1=x1[0]
Psi2=psi2[0]

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_1=x1[100]-0
d_x2_1=x2[100]-1

print('\nНевязки: ', d_x1_1,d_x2_1)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.3 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-1.9+delta_psi2 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_2=x1[100]-0
d_x2_2=x2[100]-1

print('\nНевязки: ', d_x1_2,d_x2_2)
 #_______________________________________________________________________________________________________________________
x1[0]=-0.3+delta_x1 # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=-1.9 # parametr

for i in range(1,101):
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])

df = pd.DataFrame(np.array([x1,x2,psi1,psi2]).T)
print(df)

d_x1_3=x1[100]-0
d_x2_3=x2[100]-1

print('\nНевязки: ', d_x1_3,d_x2_3)
 #_______________________________________________________________________________________________________________________
a11=(d_x1_2-d_x1_1)/0.01
a12=(d_x1_3-d_x1_1)/0.01
a21=(d_x2_2-d_x2_1)/0.01
a22=(d_x2_3-d_x2_1)/0.01

b1=a11*Psi2+a12*X1-d_x1_1
b2=a21*Psi2+a22*X1-d_x2_1

x1[0]=(b2*a11-b1*a21)/(a22*a11-a12*a21) # parametr
x2[0]=0 # is done
psi1[0]=2*x1[0] # is done #???
psi2[0]=(b1*a22-b2*a12)/(a22*a11-a12*a21) # parametr
u[0]=psi2[0]/2

for i in range(1,101):
  print(i)
  x1[i]=x1[i-1]+delta_t*x2[i-1]
  x2[i]=x2[i-1]+delta_t*(psi2[i-1]/2-x1[i-1]*math.exp(-alpha[0]*x1[i-1]))
  psi1[i]=psi1[i-1]+delta_t*(psi2[i-1]*math.exp(-alpha[0]*x1[i-1])*(1-alpha[0]*x1[i-1]))
  psi2[i]=psi2[i-1]+delta_t*(-psi1[i-1])
  u[i]=psi2[i]/2

df = pd.DataFrame(np.array([x1,x2,psi1,psi2,u]).T)
print(df)

d_x1_4=x1[100]-0
d_x2_4=x2[100]-1

print('\nНевязки: ', d_x1_4,d_x2_4)
 #_______________________________________________________________________________________________________________________

x1_inv[0]=x1[100] # parametr
x2_inv[0]=x2[100] # is done
psi1_inv[0]=psi1[100] # is done #???
psi2_inv[0]=psi2[100] # parametr
u_inv[0]=u[100]

for i in range(1,101):
  x1_inv[i]=x1_inv[i-1]-delta_t*x2_inv[i-1]
  x2_inv[i]=x2_inv[i-1]-delta_t*(psi2_inv[i-1]/2-x1_inv[i-1]*math.exp(-alpha[0]*x1_inv[i-1]))
  psi1_inv[i]=psi1_inv[i-1]-delta_t*(psi2_inv[i-1]*math.exp(-alpha[0]*x1_inv[i-1])*(1-alpha[0]*x1_inv[i-1]))
  psi2_inv[i]=psi2_inv[i-1]-delta_t*(-psi1_inv[i-1])
  u_inv[i]=psi2_inv[i]/2

df = pd.DataFrame(np.array([x1_inv,x2_inv,psi1_inv,psi2_inv,u_inv]).T)
print(df)

x1_inv=x1_inv[::-1]
x2_inv=x2_inv[::-1]
u_inv=u_inv[::-1]
 #_______________________________________________________________________________________________________________________
plt.plot(xx, x1, color='green',label='x1')
plt.plot(xx, x1_inv, color='black',label='x1_int', linestyle='dotted')
plt.plot(xx, x2, color='red',label='x2')
plt.plot(xx, x2_inv, color='blue',label='x12_int', linestyle='dotted')
plt.xlabel("n")
plt.legend()
plt.title("Экстремаль при альфа=25")
plt.show()
 #_______________________________________________________________________________________________________________________
plt.plot(xx, u, color='green',label='u')
plt.plot(xx, u_inv, color='red',label='u_int', linestyle='dotted')
plt.xlabel("n")
plt.legend()
plt.title("управление при альфа=25")
plt.show()
# Out:
#               0           1           2            3
# 0     -0.300000    0.000000   -0.600000    -1.900000
# 1     -0.300000    8.505277 -459.270721    -1.890575
# 2     -0.166399   17.010627 -915.666247     5.323632
# 3      0.100803   17.219906 -888.020059    19.706884
# 4      0.371293   17.374557 -888.057916    33.655871
# ..          ...         ...         ...          ...
# 96   258.978959  500.310491 -888.058324  1317.017918
# 97   266.837818  510.654325 -888.058324  1330.967505
# 98   274.859157  521.107720 -888.058324  1344.917093
# 99   283.044698  531.670674 -888.058324  1358.866681
# 100  291.396162  542.343188 -888.058324  1372.816268
#
# [101 rows x 4 columns]
#
# Невязки:  291.39616180658396 541.3431876086037
#               0           1           2            3
# 0     -0.300000    0.000000   -0.600000    -1.890000
# 1     -0.300000    8.505355 -456.856664    -1.880575
# 2     -0.166398   17.010784 -910.838134     5.295712
# ...
